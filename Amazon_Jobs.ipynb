# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
import re

# %%
# 打开初始程序包
wd = webdriver.Chrome(r'/Users/tingkangzhao/SeleniumDriver/chromedriver')

# 等待（最大等待时长10s）
wd.implicitly_wait(5)
# Out:
# /var/folders/yh/d_jgns49545bkkpm4rst2c_80000gn/T/ipykernel_19463/749435398.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome(r'/Users/tingkangzhao/SeleniumDriver/chromedriver')

# %%
url = "https://amazon.jobs/en/search?offset=0&result_limit=10&sort=relevant&category%5B%5D=operations-it-support-engineering&category%5B%5D=software-development&category%5B%5D=hardware-development&category%5B%5D=business-merchant-development&category%5B%5D=machine-learning-science&category%5B%5D=project-program-product-management-technical&category%5B%5D=economics&category%5B%5D=research-science&category%5B%5D=systems-quality-security-engineering&category%5B%5D=business-intelligence&category%5B%5D=design&category%5B%5D=buying-planning-instock-management&category%5B%5D=data-science&category%5B%5D=supply-chain-transportation-management&category%5B%5D=audio-video-photography-production&category%5B%5D=database-administration&country%5B%5D=USA&distanceType=Mi&radius=24km&latitude=&longitude=&loc_group_id=&loc_query=&base_query=&city=&country=&region=&county=&query_options=&"
wd.get(url)

# %%
job_titles = wd.find_elements(By.CLASS_NAME, "job-tile")

# %%
location_id_lst = []
link_lst = []
posted_lst = []
qualification_lst = []
title_lst = []


for job_title in job_titles:
    location_id_lst.append(job_title.find_element(By.CSS_SELECTOR, "p").text)
    link_lst.append(job_title.find_element(By.CSS_SELECTOR, '[href]').get_attribute('href'))
    posted_lst.append(job_title.find_element(By.CSS_SELECTOR, 'h2.posting-date').text)
    qualification_lst.append(job_title.find_element(By.CSS_SELECTOR, 'div.qualifications-preview').text)
    title_lst.append(job_title.find_element(By.CSS_SELECTOR, 'h3.job-title').text)
    
print(location_id_lst)
print(link_lst)
print(posted_lst)
print(qualification_lst)
print(title_lst)
# Out:
# ['USA, WA, Seattle | Job ID: 2173778', 'USA, VA, Arlington | Job ID: 2276985', 'USA, VA, Herndon | Job ID: 2326968', 'USA, MN, Minneapolis | Job ID: 2322300', 'USA, WA, Seattle | Job ID: 2322215', 'USA, MA, Westborough | Job ID: 2293540', 'USA, CA, Cupertino | Job ID: 2331199', 'USA, WA, Seattle | Job ID: 2331201', 'USA, TX, Houston | Job ID: 2325284', 'USA, TX, Houston | Job ID: 2325283']
# ['https://amazon.jobs/en/jobs/2173778/2023-research-science-intern-united-states', 'https://amazon.jobs/en/jobs/2276985/it-support-engineer', 'https://amazon.jobs/en/jobs/2326968/controls-manager-us-east-controls-deployment-and-service', 'https://amazon.jobs/en/jobs/2322300/sr-manager-infrastructure-security-infrastructure-security', 'https://amazon.jobs/en/jobs/2322215/sr-manager-of-internet-optimization-services-aws-internet-optimization', 'https://amazon.jobs/en/jobs/2293540/amazon-robotics-applied-scientist-co-op-navigation-technologies-2023', 'https://amazon.jobs/en/jobs/2331199/senior-technical-program-manager-storage-memory-technologies', 'https://amazon.jobs/en/jobs/2331201/network-development-engineer-iii-adc-networking', 'https://amazon.jobs/en/jobs/2325284/burrow-edge-dco-tech', 'https://amazon.jobs/en/jobs/2325283/burrow-edge-dco-tech']
# ['Posted July 28, 2022', 'Posted October 17, 2022', 'Posted February 8, 2023', 'Posted January 26, 2023', 'Posted January 26, 2023', 'Posted November 2, 2022', 'Posted February 20, 2023', 'Posted February 20, 2023', 'Posted February 3, 2023', 'Posted February 3, 2023']
# ["Basic qualifications:\nEnrolled in a Master's degree or equivalent in computer science, statistics, physics, engineering, or related topics.\nExperience in designing experiments and statistical analysis of results.\nExperience in understanding and ability to implement algorithms using both toolkits and self-developed code.", 'Basic qualifications:\nBachelor’s degree in Computer science or IT related field, or 2+ year’s IT systems or relevant experience.\n2+ years of experience in technical help-desk or desk-side support environment', 'Basic qualifications:\nB.S. in Electrical, Mechanical, or other related engineering degrees as well as 10+ years Controls related experience; or Associates degree and 12 years of Controls related experience; or High School diploma with 15 years of Controls related experience', "Basic qualifications:\nA background in computer science fundamentals: a bachelor's degree or higher in Computer Science (or equivalent).\n10+ years of experience in software leadership roles; technical security leadership roles, or security executive roles", 'Basic qualifications:\n7+ years of experience working directly within software engineering teams\nExperience partnering with product OR program management teams\n3+ years of people management experience, managing engineers', 'Basic qualifications:\nCurrently enrolled in a PhD in Robotics, Engineering, or another similar field with a graduation date of August 2023 or later\nMust be eligible and available to work full-time (40 hours per week) in the United States for a 6-month internship', 'Basic qualifications:\nBachelor’s degree in Electrical Engineering, Computer Engineering, or related field\n6+ years of experience in hardware development\n6+ years of experience in storage systems or related field', 'Basic qualifications:\nThis position requires that the candidate selected be a US citizen and obtain and maintain an active TS/SCI security clearance with polygraph.\nBachelor’s degree in a technical discipline or equivalent experience in a large–scale network environment', 'Basic qualifications:\nBachelor’s Degree (BA or BS) in information technology or computer science or equivalent work experience.\n2+ years of Computer Hardware, including troubleshooting and repair skills.', 'Basic qualifications:\nBachelor’s Degree (BA or BS) in information technology or computer science or equivalent work experience.\n2+ years of Computer Hardware, including troubleshooting and repair skills.']
# ['2023 Research Science Intern - United States', 'IT Support Engineer', 'Controls Manager - US East, Controls Deployment and Service', 'Sr. Manager, Infrastructure Security, Infrastructure Security', 'Sr. Manager of Internet Optimization Services - AWS, Internet Optimization', 'Amazon Robotics - Applied Scientist Co-op (Navigation Technologies) - 2023', 'Senior Technical Program Manager, Storage & Memory Technologies', 'Network Development Engineer III, ADC Networking', 'BURROW EDGE DCO Tech', 'BURROW EDGE DCO Tech']

# %%
location_lst = []
id_lst = []
for i in location_id_lst:
    temp = i.split('|')
    location_lst.append(temp[0])
    id_lst.append(temp[1])

# %%
jobs_dic = {}
for i in range(len(id_lst)):
    job_dic = {}
    job_dic["jobID"] = id_lst[i][9:]
    job_dic["origin_search"] = None
    job_dic["posted"] = posted_lst[i]
    job_dic["jobTitle"] = title_lst[i]
    job_dic["companyName"] = "Amazon"
    job_dic["link"] = link_lst[i]
    location_dic = {}
    location_dic["remote"] = "not specified"
    location_dic["city"] = location_lst[i].split(', ')[2]
    location_dic["state"] = location_lst[i].split(', ')[1]
    location_dic["country"] = location_lst[i].split(', ')[0]
    job_dic["jobLocation"] = location_dic
    job_dic["educationRequirement"] = {"edication":None, "major":None}
    job_dic["jobType"] = None
    job_dic["visaSponsorship"] = None
    job_dic["salary"] = None
    job_dic["benefits"] = None
    job_dic["requirements"] = qualification_lst[i]
    job_dic["jobDescription"] = None
    jobs_dic[job_dic["jobID"]] = job_dic

# %%
jobs_dic
# Out:
# {'2323847': {'jobID': '2323847',
#   'origin_search': None,
#   'posted': 'Posted January 31, 2023',
#   'jobTitle': 'Sr. Supplier Quality Engineer (Electrical), Project Kuiper',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2323847/sr-supplier-quality-engineer-electrical-project-kuiper',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Redmond ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\nBachelor’s Degree in Engineering, Materials Science or related discipline, or equivalent experience.\n5+ years of PCBA quality, manufacturing or design engineering experience',
#   'jobDescription': None},
#  '2325396': {'jobID': '2325396',
#   'origin_search': None,
#   'posted': 'Posted February 3, 2023',
#   'jobTitle': 'Sr. I&T Engineer, Kuiper Ground Systems',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2325396/sr-i-t-engineer-kuiper-ground-systems',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Redmond ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\n6+ years of experience in integration and test and/or product verification and validation roles\n3+ years of experience using RF and Network test equipment associated with SATCOM communications',
#   'jobDescription': None},
#  '2314681': {'jobID': '2314681',
#   'origin_search': None,
#   'posted': 'Posted January 4, 2023',
#   'jobTitle': 'Sr. Ground Systems Engineer , Kuiper Ground Systems',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2314681/sr-ground-systems-engineer-kuiper-ground-systems',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Redmond ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Bachelor’s degree in electrical engineering, physics, or related degree, or equivalent experience. 5+ years of system engineering experience in development and delivery of satellite communications systems.',
#   'jobDescription': None},
#  '2324043': {'jobID': '2324043',
#   'origin_search': None,
#   'posted': 'Posted February 1, 2023',
#   'jobTitle': 'Sr. Manager of User Research, Prime Video',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2324043/sr-manager-of-user-research-prime-video',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Seattle ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\n7+ years of UX research management experience\n10+ years of experience with research methods including: field research, usability, focus groups, survey design, and data analysis including statistical measures.',
#   'jobDescription': None},
#  '2331746': {'jobID': '2331746',
#   'origin_search': None,
#   'posted': 'Posted February 21, 2023',
#   'jobTitle': 'Sr. Firmware Wireless Engineer, Antenna Systems',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2331746/sr-firmware-wireless-engineer-antenna-systems',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Redmond ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\n5+ years of non-internship professional software development experience\n5+ years of programming with at least one software programming language experience',
#   'jobDescription': None},
#  '2331745': {'jobID': '2331745',
#   'origin_search': None,
#   'posted': 'Posted February 21, 2023',
#   'jobTitle': 'Sr. System Dev Engineer – Antenna, Antenna Systems',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2331745/sr-system-dev-engineer-antenna-antenna-systems',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Redmond ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\n5+ years of programming with at least one modern language such as C++, C#, Java, Python, Golang, PowerShell, Ruby experience\nBS or MS in electrical engineering, computer engineering or computer science, or equivalent experience',
#   'jobDescription': None},
#  '2331740': {'jobID': '2331740',
#   'origin_search': None,
#   'posted': 'Posted February 21, 2023',
#   'jobTitle': 'Senior HW Dev Engineer - Antenna Systems',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2331740/senior-hw-dev-engineer-antenna-systems',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Redmond ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\nBS degree in electrical engineering or computer engineering, or equivalent experience\n7+ years of industrial experience especially board level analog/digital design',
#   'jobDescription': None},
#  '2331739': {'jobID': '2331739',
#   'origin_search': None,
#   'posted': 'Posted February 21, 2023',
#   'jobTitle': 'HW Dev Engineer - Antenna Systems, Antenna Systems',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2331739/hw-dev-engineer-antenna-systems-antenna-systems',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Redmond ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\nBS degree in electrical engineering or computer engineering, or equivalent experience\n3+ years of industrial experience especially board level analog/digital design',
#   'jobDescription': None},
#  '2331731': {'jobID': '2331731',
#   'origin_search': None,
#   'posted': 'Posted February 21, 2023',
#   'jobTitle': 'Facility Manager',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2331731/facility-manager',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Ashburn ',
#    'state': 'VA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': "Basic qualifications:\nBachelor's degree in a relevant engineering discipline or Equivalent work experience in Mechanical/Electrical Field\n5+ years of experience in a management position with 5 or more direct reports",
#   'jobDescription': None},
#  '2173792': {'jobID': '2173792',
#   'origin_search': None,
#   'posted': 'Posted July 28, 2022',
#   'jobTitle': '2023 Research Science Internship - United States',
#   'companyName': 'Amazon',
#   'link': 'https://amazon.jobs/en/jobs/2173792/2023-research-science-internship-united-states',
#   'jobLocation': {'remote': 'not specified',
#    'city': 'Seattle ',
#    'state': 'WA',
#    'country': 'USA'},
#   'educationRequirement': {'edication': None, 'major': None},
#   'jobType': None,
#   'visaSponsorship': None,
#   'salary': None,
#   'benefits': None,
#   'requirements': 'Basic qualifications:\nEnrolled in a Ph.D. degree or equivalent in operations research or technologies, computer science, statistics, physics, engineering, or related topics.\nExperience in designing experiments and statistical analysis of results.',
#   'jobDescription': None}}

# %%
# Next Page
wd.find_element(By.CSS_SELECTOR, 'button.btn.circle.right').click()

# %%
wd.quit()
